# %%
N, d =  (..., ...)
keys = [(..., 47041), (..., 43997), (..., 64327), (..., 61091), (..., 41333), (..., 43753), (..., 49297), (..., 60859), (..., 62549), (..., 61603)]
ct =  ...

# %%
from Crypto.Util.number import getPrime, bytes_to_long, inverse

flag = b"Flag{XXXXXXXXXXXXXXXXXX}"

p = getPrime(1024)
q = getPrime(1024)
N = p*q
phi = (p-1)*(q-1)
e = 65537
d = inverse(e, phi)

my_key = (N, d)

keys = [(N, getPrime(16)) for i in range(10)]

cipher = bytes_to_long(flag)

for key in keys:
    cipher = pow(cipher, key[1], key[0])

print("- My private key",my_key)
print("- keys",keys)
print("- Encrypted DATA",cipher)

# %%
e = 65537
k = e*d - 1
k
# Out:
# ...

# %%
from tqdm import tqdm

fs = [2]*8 + [3]*4 +  [7 , 83 , 881 , 3863 , 619981151] + [...]

n = len(fs)
for mask in tqdm(range(1, 1 << n)):
    prod = 1
    for i in range(n):
        if (mask & (1 << i)):
            prod *= i
    prod += 1
    if is_prime(prod) and int(prod).bit_length() > 100:
        p = prod
        print('found')
        break
# Out:
# 100%|██████████| 262143/262143 [00:09<00:00, 26925.57it/s]

# %%
def get_factor(N, e, d):
    from gmpy2 import next_prime
    f = e*d - 1
    s = 0
    while f % 2 == 0: s, f = s + 1, f // 2
    i, a = s, 2
    while True:
        b = pow(a, f, N)
        if b == 1 or b == N - 1:
            a = next_prime(a)
        elif i != 1:
            while True:
                c = pow(b, 2, N)
                if c != 1:
                    b, i = c, i - 1
                else:
                    break
        else:
            break
    p = GCD(b - 1, N)
    q = N // p
    return p, q
               
        
get_factor(N, e, d)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-336cfc392f54> in <module>
#      23
#      24
# ---> 25 get_factor(N, e, d)
#
# <ipython-input-10-336cfc392f54> in get_factor(N, e, d)
#       6     i, a = s, Integer(2)
#       7     while True:
# ----> 8         b = pow(a, f, N)
#       9         if b == Integer(1) or b == N - Integer(1):
#      10             a = next_prime(a)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/rings/integer.pyx in sage.rings.integer.Integer.__pow__ (build/cythonized/sage/rings/integer.c:15119)()
#    2199         if modulus is not None:
#    2200             from sage.rings.finite_rings.integer_mod import Mod
# -> 2201             return Mod(left, modulus) ** right
#    2202
#    2203         if type(left) is type(right):
#
# ...

# %%
import sys

pt = sys.argv[1]
key = sys.argv[2]

s = list(pt)
for j in xrange(len(key)):
    key = key[1:] + key[:1]
    for i in xrange(len(s)):
        s[i] = chr(ord(s[i]) ^ ord(key[i % len(key)]))

open("flag.enc", "w").write("".join(s))

# %%
# !pip install z3-solver
# Out:
# ...
#      |▍                               | 61 kB 382 kB/s eta 0:00:13ERROR: Could not install packages due to an OSError: [Errno 28] No space left on device
#
# WARNING: You are using pip version 21.0.1; however, version 24.0 is available.
# You should consider upgrading via the '/opt/sagemath-9.3/local/bin/python3 -m pip install --upgrade pip' command.

# %%
with open('E://OTMP/')
